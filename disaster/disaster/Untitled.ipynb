# %%
import os
import pandas as pd

folder_path = r"C:/Users/USER/Downloads/earthquake"  # <-- Updated path

columns_to_keep = ['latitude', 'longitude', 'mag', 'place', 'id', 'depth']
df_list = []

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        path = os.path.join(folder_path, file)
        try:
            df = pd.read_csv(path, usecols=columns_to_keep)
            df_list.append(df)
            print(f"Processed: {file}")
        except Exception as e:
            print(f"Skipped {file} due to: {e}")

merged_df = pd.concat(df_list, ignore_index=True)

output_path = os.path.join(folder_path, "earthquakes_combined_clean.csv")
merged_df.to_csv(output_path, index=False)

print(f"\nMerged file saved to: {output_path}")
# Out:
# Processed: 2020jan2020jun.csv
# Processed: 2020july2020dec.csv
# Processed: 2021jan2021jun.csv
# Processed: 2021july2021dec.csv
# Processed: 2022jan2022june.csv
# Processed: 2022july2022dec.csv
# Processed: 2023jan2023jun.csv
# Processed: 2023july2023dec.csv
# Processed: 2024jan2024jun.csv
# Processed: 2024july2024dec.csv
# Processed: 2025.csv
# Skipped earthquakes_combined_clean.csv due to: Usecols do not match columns, columns expected but not found: ['depth', 'id']
#
# Merged file saved to: C:/Users/USER/Downloads/earthquake\earthquakes_combined_clean.csv
